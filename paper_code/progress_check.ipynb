# %%
import pandas as pd

# %%
pd.read_pickle('./test_cost/df_test_costs8_100_dnn_final_test_noClass.pkl')#.loc[0.5,1.5]
# Out:
#                                                    0.5   \
# 0.5   (0.00021853606449440122, 0.6614823937416077, 3...
# 1.0                                              931230
# 1.5                                                 NaN
# 2.0                                                 NaN
# 2.5                                                 NaN
# 3.0                                                 NaN
# 3.5                                                 NaN
# 4.0                                                 NaN
# 4.5                                                 NaN
# 5.0                                                 NaN
# 5.5                                                 NaN
# 6.0                                                 NaN
# 6.5                                                 NaN
# 7.0                                                 NaN
# 7.5                                                 NaN
# 8.0                                                 NaN
# ...

# %%
pd.read_pickle('./test_cost/df_test_costs8_20000_dnn_final_test_noClass.pkl')#.loc[0.5,1.5]
# Out:
#                                                    0.5   \
# 0.5   (0.05248630419373512, 0.43200522661209106, 192...
# 1.0                                              931230
# 1.5   (0.052291978150606155, 0.25599896907806396, 15...
# 2.0   (0.04837728291749954, 0.20724931359291077, 138...
# 2.5   (0.04196539148688316, 0.19458726048469543, 128...
# 3.0   (0.043083690106868744, 0.1506713181734085, 117...
# 3.5   (0.04002106934785843, 0.14605168998241425, 114...
# 4.0   (0.03980712592601776, 0.1412120908498764, 117....
# 4.5   (0.03911725804209709, 0.14177566766738892, 115...
# 5.0   (0.035603683441877365, 0.11572358757257462, 10...
# 5.5   (0.033117953687906265, 0.11435253918170929, 10...
# 6.0   (0.03565819561481476, 0.11503568291664124, 108...
# 6.5   (0.03357159346342087, 0.10347463935613632, 101...
# 7.0   (0.034826889634132385, 0.1035953164100647, 101...
# 7.5   (0.03265539929270744, 0.09013737738132477, 96....
# 8.0   (0.03353021666407585, 0.09640124440193176, 98....
# ...
